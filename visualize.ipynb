# %%
import numpy as np
import nibabel as nib
import nilearn
from nilearn import plotting
import os

# %% [markdown]
# 使用 BrainlAC 自带的 hd-bet 去颅骨

# %%
img_hdbet_origin = '/mnt/data/haoyang/workspace/hw/cn/dataset/UKB_T1_100cases/1011021/T1.nii.gz'
plotting.plot_img(img_hdbet_origin)

# %%
img_hdbet = '/mnt/data/haoyang/workspace/hw/cn/dataset/processed_brainiac/UKB/images/1011021.nii.gz'
plotting.plot_img(img_hdbet)

# %% [markdown]
# hd-bet 失败后由 src/preprocess.py:232 提供的 fallback_skull_strip 处理（已经修复，现该图片成功使用 hd-bet 处理，原因不详）

# %%
img_hdbetfail_origin = '/mnt/data/haoyang/workspace/hw/cn/dataset/UKB_T1_100cases/1371913/T1.nii.gz'
plotting.plot_img(img_hdbetfail_origin)

# %%
img_hdbetfail = '/mnt/data/haoyang/workspace/hw/cn/dataset/processed_brainiac/UKB/images/1371913.nii.gz'
plotting.plot_img(img_hdbetfail)

# %%
img_adni_origin = "/mnt/data/haoyang/workspace/hw/cn/dataset/ADNI_data/002_S_0619/002_S_0619-79.5-Male-Dementia-2-2.nii"
plotting.plot_img(img_adni_origin)

# %%
img_adni = "/mnt/data/haoyang/workspace/hw/cn/dataset/processed_brainiac/ADNI/images/002_S_0619.nii.gz"
plotting.plot_img(img_adni)
